# %%
#Code for CAN data processing here 
#import his python shell 
#rq fixing the main file so that I can actually import it 
import can 
from CanReader import CanReader
message=can.Message()
print(message)

message2=can.Message(data=[1,2,3,4])
print(message2)

#create test message
# Out:
# Timestamp:        0.000000    ID: 00000000    X Rx                DL:  0
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 8
#       6 message=can.Message()
#       7 print(message)
# ----> 8 print(message.timestamp())
#       9 message2=can.Message(data=[1,2,3,4])
#      10 print(message2)
#
# TypeError: 'float' object is not callable
